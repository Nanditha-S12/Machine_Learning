# %% [markdown]
# <a href="https://colab.research.google.com/github/2348536/Machine_Learning/blob/main/ML_LAB4ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Groceries_dataset.csv")

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
transactions=[]
for index,row in df.iterrows():
  transactions.append(row.dropna().tolist())

# %%
df_encoded = pd.get_dummies(df, columns=['itemDescription'])

# %%
df.describe()
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
df.shape
# Out:
# (38765, 3)

# %%
rows_to_drop=3500
df.drop(df.index[:rows_to_drop],inplace=True)
