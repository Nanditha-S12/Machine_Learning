# %% [markdown]
# <a href="https://colab.research.google.com/github/2348536/Machine_Learning/blob/main/AML_prgrm_lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Polynomial Regression
#
# Polynomial regression is a form of Linear regression where only due to the Non-linear relationship between dependent and independent variables, we add some polynomial terms to linear regression to convert it into Polynomial regression.
#
# Equation: y = β 0 + β 1 x 1 + β 2 x 2 + β 3 x 3 + ϵ, Where d is called the degree of the polynomial
#
# Dataset Description
#
# The dataset contains outdoor temperature and pressure data between the duration as given in the timestamp. The dataset is presented in OS_time, temperature, pressure humidity and actual date and time format. Interesting patterns between temperatures, pressure can be found for understanding the humidity or rainfall during the given period. This can also be used to understand environmental changes over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/Program_4_Dataset (1).csv')

# %%
df.head()
# Out:
#    index  OS_Time_Stamp  Temperature  Pressure  Humidity  \
# 0      0     1456761674         17.7    1015.2      76.4
# 1      1     1456761733         17.7    1015.3      76.4
# 2      2     1456761792         17.7    1015.3      76.5
# 3      3     1456761853         17.7    1015.3      76.7
# 4      4     1456761912         17.6    1015.2      76.8
#
#                    TimeStamp
# 0  2016-03-01 00:01:14+08:00
# 1  2016-03-01 00:02:13+08:00
# 2  2016-03-01 00:03:12+08:00
# 3  2016-03-01 00:04:13+08:00
# 4  2016-03-01 00:05:12+08:00

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       index  OS_Time_Stamp  Temperature  Pressure  Humidity  \
# 0         0     1456761674         17.7    1015.2      76.4
# 1         1     1456761733         17.7    1015.3      76.4
# 2         2     1456761792         17.7    1015.3      76.5
# 3         3     1456761853         17.7    1015.3      76.7
# 4         4     1456761912         17.6    1015.2      76.8
# ...     ...            ...          ...       ...       ...
# 2873    118     1456768752         16.7    1015.1      81.9
# 2874    119     1456768823         16.7    1015.1      82.0
# 2875    120     1456768873         16.7    1015.1      81.9
# 2876    121     1456768932         16.7    1015.1      81.7
# 2877    122     1456768992         16.6    1015.1      81.4
#
#                       TimeStamp
# 0     2016-03-01 00:01:14+08:00
# 1     2016-03-01 00:02:13+08:00
# 2     2016-03-01 00:03:12+08:00
# 3     2016-03-01 00:04:13+08:00
# 4     2016-03-01 00:05:12+08:00
# ...

# %%
df.shape
# Out:
# (2878, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of       index  OS_Time_Stamp  Temperature  Pressure  Humidity  \
# 0         0     1456761674         17.7    1015.2      76.4
# 1         1     1456761733         17.7    1015.3      76.4
# 2         2     1456761792         17.7    1015.3      76.5
# 3         3     1456761853         17.7    1015.3      76.7
# 4         4     1456761912         17.6    1015.2      76.8
# ...     ...            ...          ...       ...       ...
# 2873    118     1456768752         16.7    1015.1      81.9
# 2874    119     1456768823         16.7    1015.1      82.0
# 2875    120     1456768873         16.7    1015.1      81.9
# 2876    121     1456768932         16.7    1015.1      81.7
# 2877    122     1456768992         16.6    1015.1      81.4
#
#                       TimeStamp
# 0     2016-03-01 00:01:14+08:00
# 1     2016-03-01 00:02:13+08:00
# 2     2016-03-01 00:03:12+08:00
# 3     2016-03-01 00:04:13+08:00
# 4     2016-03-01 00:05:12+08:00
# ...

# %%
df.isnull()
# Out:
#       index  OS_Time_Stamp  Temperature  Pressure  Humidity  TimeStamp
# 0     False          False        False     False     False      False
# 1     False          False        False     False     False      False
# 2     False          False        False     False     False      False
# 3     False          False        False     False     False      False
# 4     False          False        False     False     False      False
# ...     ...            ...          ...       ...       ...        ...
# 2873  False          False        False     False     False      False
# 2874  False          False        False     False     False      False
# 2875  False          False        False     False     False      False
# 2876  False          False        False     False     False      False
# 2877  False          False        False     False     False      False
#
# [2878 rows x 6 columns]

# %% [markdown]
# Consider Temperature as predictor and the target as pressure

# %%
predictor = df[['Temperature']]
target = df['Pressure']

# %% [markdown]
# Build a model using polynomial regression with at least 6 different degrees with 3 different train-test split as 66-44, 70-30, 80-20.
#
# To build models using polynomial regression with six different degrees and three different train-test split ratios (66-44, 70-30, 80-20), nested loops can be used to iterate over the degrees and split ratios while fitting the models.

# %%
degrees = [2, 3, 4, 5, 6, 7]
split_ratios = [0.66, 0.7, 0.8]

# for loop to iterate over the degrees and split_ratios

for degree in degrees:
    for split_ratio in split_ratios:
        X_train, X_test, y_train, y_test = train_test_split(predictor, target, test_size=1 - split_ratio, random_state=42)


        poly = PolynomialFeatures(degree=degree)
        X_train_poly = poly.fit_transform(X_train)
        X_test_poly = poly.transform(X_test)


        model = LinearRegression()
        model.fit(X_train_poly, y_train)

        y_pred = model.predict(X_test_poly)

        r_squared = r2_score(y_test, y_pred)
        print(f"Degree: {degree}, Split Ratio: {split_ratio}, R-squared: {r_squared}")
        if degree == 2 and split_ratio == 0.66:
            plt.scatter(X_test, y_test, color='blue', label='Actual')
            plt.scatter(X_test, y_pred, color='red', label='Predicted')
            plt.xlabel('Temperature')
            plt.ylabel('Pressure')
            plt.legend()
            plt.title('Polynomial Regression (Degree=2) - Train-Test Split 66-34')
            plt.show()
# Out:
# Degree: 2, Split Ratio: 0.66, R-squared: 0.6266694111938397
# Degree: 2, Split Ratio: 0.7, R-squared: 0.64527735998073
# Degree: 2, Split Ratio: 0.8, R-squared: 0.6263280190072713
# Degree: 3, Split Ratio: 0.66, R-squared: 0.6429539020521366
# Degree: 3, Split Ratio: 0.7, R-squared: 0.6571658253546484
# Degree: 3, Split Ratio: 0.8, R-squared: 0.634678388154881
# Degree: 4, Split Ratio: 0.66, R-squared: 0.6828200324619633
# Degree: 4, Split Ratio: 0.7, R-squared: 0.6941666046410397
# Degree: 4, Split Ratio: 0.8, R-squared: 0.6724506321807433
# Degree: 5, Split Ratio: 0.66, R-squared: 0.6945536198701664
# Degree: 5, Split Ratio: 0.7, R-squared: 0.7042085681914689
# Degree: 5, Split Ratio: 0.8, R-squared: 0.6829249359241117
# Degree: 6, Split Ratio: 0.66, R-squared: 0.7078162513455158
# Degree: 6, Split Ratio: 0.7, R-squared: 0.7175240834347205
# Degree: 6, Split Ratio: 0.8, R-squared: 0.6955199132228507
# Degree: 7, Split Ratio: 0.66, R-squared: 0.7148201935008502
# ...

# %% [markdown]
# Inference
#
# Degree 2 Models
#
# For the split ratios 0.7 and 0.8, the R-squared values are 0.645 and 0.626, respectively. These R-squared values indicate that around 64.5% and 62.6% of the variance in the 'Pressure' variable can be explained by the models for these split ratios, based on the 'Temperature' predictor variable.
#
# Degree 3 Models
#
# R-squared values for split ratios 0.66, 0.7, and 0.8 are approximately 0.643, 0.657, and 0.635, respectively. These values suggest that around 64.3%, 65.7%, and 63.5% of the variance in 'Pressure' is explained by the models built with polynomial degree 3.
#
# Degree 4 Models
#
# For split ratios 0.66, 0.7, and 0.8, the R-squared values are approximately 0.683, 0.694, and 0.672, respectively. These values indicate that around 68.3%, 69.4%, and 67.2% of the variance in 'Pressure' is explained by the models with polynomial degree 4.
#
# Degree 5 Models
#
# R-squared values for split ratios 0.66, 0.7, and 0.8 are about 0.695, 0.704, and 0.683, respectively. These values suggest that around 69.5%, 70.4%, and 68.3% of the variance in 'Pressure' is explained by the models with polynomial degree 5.
#
# Degree 6 Models
#
# For split ratios 0.66, 0.7, and 0.8, the R-squared values are roughly 0.708, 0.718, and 0.696, respectively. These values indicate that around 70.8%, 71.8%, and 69.6% of the variance in 'Pressure' is explained by the models with polynomial degree 6.
#
# Degree 7 Models
#
# R-squared values for split ratios 0.66, 0.7, and 0.8 are approximately 0.715, 0.721, and 0.704, respectively. These values suggest that around 71.5%, 72.1%, and 70.4% of the variance in 'Pressure' is explained by the models with polynomial degree 7.
#
# Importance of R-squared
#
# R-squared in polynomial regression is a statistical measure that indicates how well a polynomial regression model fits the data. It represents the proportion of the variance in the dependent variable that is predictable from the independent variable(s). Higher R-squared values indicate a better fit.

# %% [markdown]
# Calculation of Evaluation metrics

# %%
r_squared = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"R-squared: {r_squared}")
print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print("---------------------------------------------")
# Out:
# R-squared: 0.7041961435935306
# Mean Squared Error: 20.999434130616496
# Mean Absolute Error: 3.1524489677729215
# ---------------------------------------------

# %% [markdown]
# Inference
#
# An R-squared of around 0.704 suggests that the model captures a considerable portion (approximately 70.4%) of the variance in 'Pressure' based on 'Temperature'.
#
# The Mean Squared Error of approximately 20.999 and Mean Absolute Error of approximately 3.152 indicate the average level of deviation or error in the model's predictions, with the MSE reflecting squared errors and the MAE reflecting absolute errors.

# %% [markdown]
# Conclusion
#
# A lower MSE implies that the model's predictions tend to have less variability and are generally closer to the actual 'Pressure' values.
#
# A lower MAE suggests that, on average, the absolute differences between predicted and actual 'Pressure' values are relatively smaller, indicating a higher level of accuracy in the predictions.
